# %% [markdown]
# # SETUP

# %%
import numpy as np
from probe_plotting2 import plot_one_line, plot_one_scatter
import matplotlib

# %%
matplotlib.rc('text', usetex=True)
matplotlib.rcParams.update({'figure.autolayout': True})

# %%
# %matplotlib inline

# %% [markdown]
# # GLOBAL OPTIONS

# %%
line_width=2
pad=12
ticks_font_size=40
label_font_size=40
legend_font_size=40
border_thickness=2.0
ticks_length=5.0
ticks_width=2.0

# %% [markdown]
# # SAMPLE DATA

# %%
x = np.linspace(0.0, 1.0, 100)
y1 = x**2
y2 = x**3
y3 = x**4

# %% [markdown]
# # PLOT_ONE_LINE

# %%
fig = plot_one_line(x, y1, line_color='green', line_width=line_width,
                    data_label=r'$y_\mathrm{1}$')
fig = plot_one_line(x, y1, line_color='green', line_width=line_width,
                    data_label=r'$y_\mathrm{2}$', fig=fig)

fig = plot_one_line(x, y1, line_color='blue', line_width=2, fig=fig,
                    x_label=r'$r\,[\mathrm{mm}]$',
                    y_label =r'$n_{\mathrm{e,i}}\,[10^{15}\,\mathrm{m}^{-3}]$',
                    pad=pad, ticks_font_size=ticks_font_size,
                    label_font_size=label_font_size, legend_font_size=legend_font_size,
                    border_thickness=border_thickness, ticks_length=ticks_length,
                    ticks_width=ticks_width, show=True, y_secondary=True,
                    xlim=(0.0, 5.0), data_label=r'$T_\mathrm{e}$',
                    y2_label=r'$T_\mathrm{e}\,[10^3\,\mathrm{K}]$', y2labelpad=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e31be6b53d17> in <module>()
#      12                     ticks_width=ticks_width, show=True, y_secondary=True,
#      13                     xlim=(0.0, 5.0), data_label=r'$T_\mathrm{e}$',
# ---> 14                     y2_label=r'$T_\mathrm{e}\,[10^3\,\mathrm{K}]$', y2labelpad=15)
#
# /home/ziky/work/probe/probe-plotting2/probe_plotting2/plotting.py in plot_one_line(x, y, y_errorbar, figsize, x_label, y_label, y2_label, line_color, data_label, line_style, line_width, xlim, ylim, y2lim, show, fig, y_secondary, ticks_font_size, label_font_size, legend_font_size, pad, border_thickness, ticks_length, ticks_width, legend_loc, fill_alpha, legend_ncol, ylabelpad, y2labelpad, xlabelpad)
#      88             fig['ax2'].tick_params(axis='both', which='major', labelsize=ticks_font_size)
#      89             fig['ax2'].tick_params(direction='inout', pad=pad)
# ---> 90             [i.set_linewidth(border_thickness) for i in fig['ax2'].spines.itervalues()]
#      91             fig['ax2'].tick_params('both', direction="in", length=ticks_length, width=ticks_width, which='major')
#      92             if y2labelpad:
#
# AttributeError: 'dict' object has no attribute 'itervalues'
# /home/ziky/.virtualenvs/plasmasolve3/lib/python3.4/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot_one_scatter(x, y, show=True)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f68cefd3a111> in <module>()
# ----> 1 plot_one_scatter(x, y, show=True)
#
# /home/cmoud/Plocha/Simulace/probe-plotting2/probe_plotting2/plotting.py in plot_one_scatter(x, y, err_x, err_y, figsize, x_label, y_label, data_label, size, show, fig, marker, alpha, fill_color, line_color, legend_fill_alpha, xlim, ylim, ticks_font_size, label_font_size, legend_font_size, pad, border_thickness, ticks_length, ticks_width, legend_loc, err_line_width, err_every, err_capthick, err_capsize)
#     146         fig['ax'].tick_params(direction='inout', pad=pad)
#     147
# --> 148         [i.set_linewidth(border_thickness) for i in fig['ax'].spines.itervalues()]
#     149
#     150         fig['ax'].tick_params('both', direction='in', length=ticks_length, width=ticks_width, which='major')
#
# AttributeError: 'dict' object has no attribute 'itervalues'
